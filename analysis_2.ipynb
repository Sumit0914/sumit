# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# load the datest
# look at the data (head, tail, sample)
#     get the information about the datatype (dtyps)
#     get the information about the columns (info)
#     check how many rows are missing in each column (isnull, isna)
#     get statistical information about the dataset (describe)
# if required, clean the dataset
#     remove the rows with missing values
#     remove the columns with missing values or they are not rquired
# if required, transform the dataset
#     convert the categorical columns to numerical columns
#     convert the numerical columns to categorical columns
# if required, convert the datatypes of the columns
# if required, create new columns
# if required, rename the columns
# if req

# %%
df = pd.read_json('flipkart_fashion_products_dataset.json')

# %%
df.head()
# Out:
#                                     _id actual_price average_rating brand  \
# 0  fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999            3.9  York
# 1  893e6980-f2a0-531f-b056-34dd63fe912c        1,499            3.9  York
# 2  eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999            3.9  York
# 3  3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999            3.9  York
# 4  750caa3d-6264-53ca-8ce1-94118a1d8951        2,999            3.9  York
#
#                    category          crawled_at  \
# 0  Clothing and Accessories 2021-02-10 20:11:51
# 1  Clothing and Accessories 2021-02-10 20:11:52
# 2  Clothing and Accessories 2021-02-10 20:11:52
# 3  Clothing and Accessories 2021-02-10 20:11:53
# 4  Clothing and Accessories 2021-02-10 20:11:53
#
#                                          description discount  \
# 0  Yorker trackpants made from 100% rich combed c...  69% off
# 1  Yorker trackpants made from 100% rich combed c...  66% off
# 2  Yorker trackpants made from 100% rich combed c...  68% off
# 3  Yorker trackpants made from 100% rich combed c...  69% off
# 4  Yorker trackpants made from 100% rich combed c...  68% off
#
#                                               images  out_of_stock  \
# 0  [https://rukminim1.flixcart.com/image/128/128/...         False
# 1  [https://rukminim1.flixcart.com/image/128/128/...         False
# 2  [https://rukminim1.flixcart.com/image/128/128/...         False
# 3  [https://rukminim1.flixcart.com/image/128/128/...         False
# 4  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                 pid                                    product_details  \
# 0  TKPFCZ9EA7H5FYZH  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1  TKPFCZ9EJZV2UVRZ  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
# 2  TKPFCZ9EHFCY5Z4Y  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...
# 3  TKPFCZ9ESZZ7YWEF  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...
# 4  TKPFCZ9EVXKBSUD7  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...
#
#               seller selling_price sub_category  \
# 0  Shyam Enterprises           921   Bottomwear
# 1  Shyam Enterprises           499   Bottomwear
# 2  Shyam Enterprises           931   Bottomwear
# 3  Shyam Enterprises           911   Bottomwear
# 4  Shyam Enterprises           943   Bottomwear
#
#                                title  \
# 0   Solid Men Multicolor Track Pants
# 1         Solid Men Blue Track Pants
# 2   Solid Men Multicolor Track Pants
# 3   Solid Men Multicolor Track Pants
# 4  Solid Men Brown, Grey Track Pants
#
#                                                  url
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...

# %%
df.shape
# Out:
# (30000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              30000 non-null  object
#  1   actual_price     30000 non-null  object
#  2   average_rating   30000 non-null  object
#  3   brand            30000 non-null  object
#  4   category         30000 non-null  object
#  5   crawled_at       30000 non-null  datetime64[ns]
#  6   description      30000 non-null  object
#  7   discount         30000 non-null  object
#  8   images           30000 non-null  object
#  9   out_of_stock     30000 non-null  bool
#  10  pid              30000 non-null  object
#  11  product_details  30000 non-null  object
#  12  seller           30000 non-null  object
#  13  selling_price    30000 non-null  object
#  14  sub_category     30000 non-null  object
#  15  title            30000 non-null  object
#  16  url              30000 non-null  object
# dtypes: bool(1), datetime64[ns](1), object(15)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                           crawled_at
# count                          30000
# mean   2021-02-10 22:55:06.673900032
# min              2021-02-10 20:11:51
# 25%              2021-02-10 21:31:38
# 50%              2021-02-10 23:01:10
# 75%              2021-02-11 00:16:29
# max              2021-02-11 01:31:55

# %%
# missing values
df.isnull().sum()
# Out:
# _id                0
# actual_price       0
# average_rating     0
# brand              0
# category           0
# crawled_at         0
# description        0
# discount           0
# images             0
# out_of_stock       0
# pid                0
# product_details    0
# seller             0
# selling_price      0
# sub_category       0
# title              0
# url                0
# dtype: int64

# %%
# removing unwanted columns
cols_to_delete = ["_id", "pid", "url", "images"]
df.drop(cols_to_delete, axis=1, inplace=True)
df.head()
# Out:
#   actual_price average_rating brand                  category  \
# 0        2,999            3.9  York  Clothing and Accessories
# 1        1,499            3.9  York  Clothing and Accessories
# 2        2,999            3.9  York  Clothing and Accessories
# 3        2,999            3.9  York  Clothing and Accessories
# 4        2,999            3.9  York  Clothing and Accessories
#
#            crawled_at                                        description  \
# 0 2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# 1 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 2 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 3 2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
# 4 2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
#
#   discount  out_of_stock                                    product_details  \
# 0  69% off         False  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1  66% off         False  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
# 2  68% off         False  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...
# 3  69% off         False  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...
# 4  68% off         False  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...
#
#               seller selling_price sub_category  \
# 0  Shyam Enterprises           921   Bottomwear
# 1  Shyam Enterprises           499   Bottomwear
# 2  Shyam Enterprises           931   Bottomwear
# 3  Shyam Enterprises           911   Bottomwear
# 4  Shyam Enterprises           943   Bottomwear
#
#                                title
# 0   Solid Men Multicolor Track Pants
# 1         Solid Men Blue Track Pants
# 2   Solid Men Multicolor Track Pants
# 3   Solid Men Multicolor Track Pants
# 4  Solid Men Brown, Grey Track Pants

# %%
def clean_price(price):
    if price is None:
        return np.nan
    elif isinstance(price, str):
        price = price.replace(",","")
        if price:
            price = float(price)
        else:
            price = np.nan
            return price
    else:
        return price


df["actual_price"] = df["actual_price"].apply(clean_price)

# %%
def clean_discount(value):
    if value is None:
        return np.nan
    elif isinstance(value, str):
        value = value.replace('% off', '')
        if value:
            value = float(value)
        else:
            value = np.nan
        return value
    else:
        return value

df['discount'] = df['discount'].apply(clean_discount)

# %%
def clean_rating(value):
    if value is None:
        return np.nan
    elif isinstance(value, str):
        if value:
            value = float(value)
        else:
            value = np.nan
        return value
    else:
        return value

df['average_rating'] = df['average_rating'].apply(clean_rating)

# %%
df['selling_price'] = df['selling_price'].apply(clean_price)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   actual_price     0 non-null      float64
#  1   average_rating   27554 non-null  float64
#  2   brand            30000 non-null  object
#  3   category         30000 non-null  object
#  4   crawled_at       30000 non-null  datetime64[ns]
#  5   description      30000 non-null  object
#  6   discount         29059 non-null  float64
#  7   out_of_stock     30000 non-null  bool
#  8   product_details  30000 non-null  object
#  9   seller           30000 non-null  object
#  10  selling_price    0 non-null      float64
#  11  sub_category     30000 non-null  object
#  12  title            30000 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(4), object(7)
# memory usage: 2.8+ MB

# %%
df.head()
# Out:
#    actual_price  average_rating brand                  category  \
# 0           NaN             3.9  York  Clothing and Accessories
# 1           NaN             3.9  York  Clothing and Accessories
# 2           NaN             3.9  York  Clothing and Accessories
# 3           NaN             3.9  York  Clothing and Accessories
# 4           NaN             3.9  York  Clothing and Accessories
#
#            crawled_at                                        description  \
# 0 2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# 1 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 2 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 3 2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
# 4 2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
#
#    discount  out_of_stock                                    product_details  \
# 0      69.0         False  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1      66.0         False  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
# 2      68.0         False  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...
# 3      69.0         False  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...
# 4      68.0         False  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...
#
#               seller  selling_price sub_category  \
# 0  Shyam Enterprises            NaN   Bottomwear
# 1  Shyam Enterprises            NaN   Bottomwear
# 2  Shyam Enterprises            NaN   Bottomwear
# 3  Shyam Enterprises            NaN   Bottomwear
# 4  Shyam Enterprises            NaN   Bottomwear
#
#                                title
# 0   Solid Men Multicolor Track Pants
# 1         Solid Men Blue Track Pants
# 2   Solid Men Multicolor Track Pants
# 3   Solid Men Multicolor Track Pants
# 4  Solid Men Brown, Grey Track Pants

# %%
df.drop_duplicates(subset='title') # just a demo
# Out:
#        actual_price  average_rating brand                  category  \
# 0               NaN             3.9  York  Clothing and Accessories
# 1               NaN             3.9  York  Clothing and Accessories
# 4               NaN             3.9  York  Clothing and Accessories
# 6               NaN             3.8  York  Clothing and Accessories
# 7               NaN             3.8  York  Clothing and Accessories
# ...             ...             ...   ...                       ...
# 29984           NaN             3.8   Oka  Clothing and Accessories
# 29987           NaN             3.8   Oka  Clothing and Accessories
# 29992           NaN             3.8   Oka  Clothing and Accessories
# 29994           NaN             3.8   Oka  Clothing and Accessories
# 29997           NaN             NaN   Oka  Clothing and Accessories
#
#                crawled_at                                        description  \
# 0     2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# 1     2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 4     2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
# 6     2021-02-10 20:11:54  Yorker trackpants made from 100% rich combed c...
# 7     2021-02-10 20:11:55  Yorker trackpants made from 100% rich combed c...
# ...                   ...                                                ...
# 29984 2021-02-11 01:31:49
# 29987 2021-02-11 01:31:50
# 29992 2021-02-11 01:31:52  ‘OKANE’ endeavors to continue to be a leader i...
# 29994 2021-02-11 01:31:53
# 29997 2021-02-11 01:31:54
#
#        discount  out_of_stock  \
# 0          69.0         False
# 1          66.0         False
# 4          68.0         False
# 6          68.0         False
# 7          63.0         False
# ...         ...           ...
# 29984      49.0         False
# 29987      34.0         False
# 29992      49.0         False
# 29994      34.0         False
# 29997      40.0          True
#
#                                          product_details             seller  \
# 0      [{'Style Code': '1005COMBO2'}, {'Closure': 'El...  Shyam Enterprises
# 1      [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...  Shyam Enterprises
# 4      [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...  Shyam Enterprises
# 6      [{'Style Code': '1005NAVI'}, {'Closure': 'Elas...  Shyam Enterprises
# 7      [{'Style Code': '1005DSKIN'}, {'Closure': 'Ela...  Shyam Enterprises
# ...                                                  ...                ...
# 29984  [{'Type': 'Round Neck'}, {'Sleeve': 'Full Slee...              OKANE
# 29987  [{'Fabric': 'Cotton Blend'}, {'Pattern': 'Colo...              OKANE
# 29992  [{'Fabric': 'Cotton Blend'}, {'Pattern': 'Soli...              OKANE
# 29994  [{'Fabric': 'Cotton Blend'}, {'Pattern': 'Chec...              OKANE
# 29997  [{'Color': 'Grey'}, {'Fabric': 'Tweed'}, {'Pat...
#
#        selling_price                   sub_category  \
# 0                NaN                     Bottomwear
# 1                NaN                     Bottomwear
# 4                NaN                     Bottomwear
# 6                NaN                     Bottomwear
# 7                NaN                     Bottomwear
# ...              ...                            ...
# 29984            NaN                        Topwear
# 29987            NaN                     Bottomwear
# 29992            NaN                     Bottomwear
# 29994            NaN                     Bottomwear
# 29997            NaN  Blazers, Waistcoats and Suits
#
#                                                    title
# 0                       Solid Men Multicolor Track Pants
# 1                             Solid Men Blue Track Pants
# 4                      Solid Men Brown, Grey Track Pants
# 6                        Solid Men Dark Blue Track Pants
# 7                            Solid Men Beige Track Pants
# ...                                                  ...
# 29984          Striped Men Round Neck Red, White T-Shirt
# 29987           Color Block Men Multicolor Sports Shorts
# 29992                       Solid Men Black Night Shorts
# 29994            Checkered Men Multicolor Regular Shorts
# 29997  Checkered Single Breasted Casual Men Full Slee...
#
# [4579 rows x 13 columns]

# %%
print(df.columns.tolist())
# Out:
# ['actual_price', 'average_rating', 'brand', 'category', 'crawled_at', 'description', 'discount', 'out_of_stock', 'product_details', 'seller', 'selling_price', 'sub_category', 'title']

# %%
# rename a column
df.rename(columns={'product_details':'details'}, inplace=True)

# %%
df.sort_values(by=['actual_price','discount'], ascending=False, inplace=True)

# %%
pricesdf = df[['title','actual_price','discount','average_rating','selling_price']]

# %%
pricesdf['discount'].plot.hist(bins=20, figsize=(10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# styling your dataframe
pricesdf.head(30).style.bar(subset=["actual_price","selling_price"], color="#330033")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # styling your dataframe
# ----> 2 pricesdf.head(30).style.bar(subset=["actual_price","selling_price"], color="#330033")
#
# NameError: name 'pricesdf' is not defined

# %%
# styling your dataframe
pricesdf.head(100).style.background_gradient(subset=['average_rating'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Ballu-PC\miniconda3\lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File c:\Users\Ballu-PC\miniconda3\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'jinja2'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[37], line 2
#       1 # styling your dataframe
# ----> 2 pricesdf.head(100).style.background_gradient(subset=['average_rating'])
#
# File c:\Users\Ballu-PC\miniconda3\lib\site-packages\pandas\core\frame.py:1291, in DataFrame.style(self)
#    1279 @property
#    1280 def style(self) -> Styler:
#    1281     """
#    1282     Returns a Styler object.
#    1283
#    (...)
#    1289         data with HTML and CSS.
#    1290     """
# -> 1291     from pandas.io.formats.style import Styler
#    1293     return Styler(self)
#
# File c:\Users\Ballu-PC\miniconda3\lib\site-packages\pandas\io\formats\style.py:56
#      52 from pandas.core.shared_docs import _shared_docs
#      54 from pandas.io.formats.format import save_to_buffer
# ---> 56 jinja2 = import_optional_dependency("jinja2", extra="DataFrame.style requires jinja2.")
#      58 from pandas.io.formats.style_render import (
#      59     CSSProperties,
#      60     CSSStyles,
#    (...)
#      68     refactor_levels,
#      69 )
#      71 if TYPE_CHECKING:
#
# File c:\Users\Ballu-PC\miniconda3\lib\site-packages\pandas\compat\_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     return None
#     148 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'Jinja2'. DataFrame.style requires jinja2. Use pip or conda to install Jinja2.
